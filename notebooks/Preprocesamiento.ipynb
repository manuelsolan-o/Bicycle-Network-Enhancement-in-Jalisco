# %%
import pandas as pd

# %%
data
# Out:
#         Viaje_Id  Usuario_Id Genero  A�o_de_nacimiento     Inicio_del_viaje  \
# 0       26751198     1350606      M             1983.0  2023-01-01 00:00:41
# 1       26751199       15163      M             1986.0  2023-01-01 00:04:48
# 2       26751200     1534764      M             1987.0  2023-01-01 00:06:49
# 3       26751201     1240140      M             1996.0  2023-01-01 00:08:05
# 4       26751202     1732214      M             1969.0  2023-01-01 00:09:14
# ...          ...         ...    ...                ...                  ...
# 366013  27176723      344644      M             2000.0  2023-01-31 23:57:49
# 366014  27176726     2057371      M             1998.0  2023-01-31 23:58:36
# 366015  27176730      355465      M             1994.0  2023-01-31 23:59:33
# 366016  27176731      152612      M             1989.0  2023-01-31 23:59:36
# 366017  27176732     1213162      M             1988.0  2023-01-31 23:59:54
#
#               Fin_del_viaje  Origen_Id  Destino_Id
# 0       2023-01-01 00:26:52        154          50
# 1       2023-01-01 00:07:46         64          79
# 2       2023-01-01 00:17:36         35          12
# 3       2023-01-01 00:09:00         35          35
# 4       2023-01-01 00:14:57         54         171
# ...                     ...        ...         ...
# 366013  2023-02-01 00:08:49        215         198
# 366014  2023-02-01 00:06:23         63          52
# 366015  2023-02-01 00:03:13         80          81
# 366016  2023-02-01 00:06:34        289         111
# 366017  2023-02-01 00:12:30        296         304
#
# [366018 rows x 8 columns]

# %%
type(data['Inicio_del_viaje'][0])
# Out:
# str

# %%
len(data['Origen_Id'].unique())
# Out:
# 300

# %%
len(data['Destino_Id'].unique())
# Out:
# 300

# %%
data2 = pd.read_csv('data/nomenclatura', encoding='ISO-8859-1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data2 = pd.read_csv('data/nomenclatura', encoding='ISO-8859-1')
#
# NameError: name 'pd' is not defined

# %%
data2
# Out:
#       id                                           name     obcn  \
# 0      2  (GDL-001) C. Epigmenio Glez./ Av. 16 de Sept.  GDL-001
# 1      3     (GDL-002) C. Colonias  / Av.  Niños héroes  GDL-002
# 2      4          (GDL-003) C. Vidrio / Av. Chapultepec  GDL-003
# 3      5           (GDL-004) C. Ghilardi /C. Miraflores  GDL-004
# 4      6  (GDL-005) C. San Diego /Calzada Independencia  GDL-005
# ..   ...                                            ...      ...
# 307  323   (GDL-213) C. Palavicini / Av. Circunvalación  GDL-213
# 308  324    (GDL-221) De los científicos/ J. J. Tablada  GDL-221
# 309  325    (GDL-226) C. Luis G. Cuevas /Av. Revolución  GDL-226
# 310  326          (GDL-219) C. D. Rivera / C. Filósofos  GDL-219
# 311  327      (GDL-227) C. Artistas / C. Carlos Pereira  GDL-227
#
#               location   latitude   longitude      status
# 0     POLÍGONO CENTRAL  20.666378 -103.348820  IN_SERVICE
# 1     POLÍGONO CENTRAL  20.667228 -103.366000  IN_SERVICE
# 2     POLÍGONO CENTRAL  20.667690 -103.368252  IN_SERVICE
# 3     POLÍGONO CENTRAL  20.691750 -103.362550  IN_SERVICE
# 4     POLÍGONO CENTRAL  20.681158 -103.339363  IN_SERVICE
# ..                 ...        ...         ...         ...
# 307   POLÍGONO CENTRAL  20.704670 -103.345589  IN_SERVICE
# 308   POLÍGONO CENTRAL  20.700192 -103.345961  IN_SERVICE
# 309  TLQ-CORREDORATLAS  20.652408 -103.312902  IN_SERVICE
# 310   POLÍGONO CENTRAL  20.698197 -103.342554  IN_SERVICE
# 311   POLÍGONO CENTRAL  20.695636 -103.339378  IN_SERVICE
#
# [312 rows x 7 columns]

# %%
len(data2.id.unique())
# Out:
# 312

# %%
import folium
import re

# %%
lat = 20.66682
lon = -103.39182 
m = folium.Map(location=(lat_Mex,lon_Mex),zoom_start=12)

# %%
for i in range(len(data2['latitude'])):
    lat = data2['latitude'][i]
    lon = data2['longitude'][i]
    info = data2[['id', 'name']].loc[i]
    info = pd.DataFrame(info)#.transpose().to_html(classes=classes) # Transpusimos la tabla
    mark = folium.Marker(location=(lat,lon),popup=info) # Agregarle la tabla
    mark.add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfe853c70cf21624c30682c2a64b83c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfe853c70cf21624c30682c2a64b83c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfe853c70cf21624c30682c2a64b83c5 = L.map(
#                 &quot;map_cfe853c70cf21624c30682c2a64b83c5&quot;,
#                 {
#                     center: [20.66682, -103.39182],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37ce9f8a6d9e73bd6c5f73e9aff0e1e1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cfe853c70cf21624c30682c2a64b83c5);
#
#
#             var marker_522411edf98c98ccb1e448af436df2c8 = L.marker(
#                 [20.666378, -103.34882],
#                 {}
#             ).addTo(map_cfe853c70cf21624c30682c2a64b83c5);
#
#
#         var popup_842ef04c9a1b60d7cbad55e2fa5853b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3e41fa2a7202e13b72cee2af0139c47 = $(`&lt;div id=&quot;html_f3e41fa2a7202e13b72cee2af0139c47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                                                  0 id                                                2 name  (GDL-001) C. Epigmenio Glez./ Av. 16 de Sept.&lt;/div&gt;`)[0];
#                 popup_842ef04c9a1b60d7cbad55e2fa5853b3.setContent(html_f3e41fa2a7202e13b72cee2af0139c47);
#
#
#
#         marker_522411edf98c98ccb1e448af436df2c8.bindPopup(popup_842ef04c9a1b60d7cbad55e2fa5853b3)
#         ;
#
#
#
#
#             var marker_f5d84fbb9f6149ee3e4454aac0989508 = L.marker(
#                 [20.667228, -103.366],
#                 {}
#             ).addTo(map_cfe853c70cf21624c30682c2a64b83c5);
#
#
#         var popup_3ba214b626ae91a7bce21e7393bb0e38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e3ad62895065c08d63d9fa5227dbcba = $(`&lt;div id=&quot;html_8e3ad62895065c08d63d9fa5227dbcba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                                               1 id                                             3 name  (GDL-002) C. Colonias  / Av.  Niños héroes&lt;/div&gt;`)[0];
#                 popup_3ba214b626ae91a7bce21e7393bb0e38.setContent(html_8e3ad62895065c08d63d9fa5227dbcba);
#
#
#
#         marker_f5d84fbb9f6149ee3e4454aac0989508.bindPopup(popup_3ba214b626ae91a7bce21e7393bb0e38)
#         ;
#
#
#
#
#             var marker_142ffea5dfc9bb2fd03bafe8406f8ba2 = L.marker(
#                 [20.66769, -103.368252],
#                 {}
#             ).addTo(map_cfe853c70cf21624c30682c2a64b83c5);
#
#
#         var popup_574ead1ad26543501c66b698f45c7988 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75a8d3c4323fde86e772dfec0743de08 = $(`&lt;div id=&quot;html_75a8d3c4323fde86e772dfec0743de08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                                          2 id                                        4 name  (GDL-003) C. Vidrio / Av. Chapultepec&lt;/div&gt;`)[0];
#                 popup_574ead1ad26543501c66b698f45c7988.setContent(html_75a8d3c4323fde86e772dfec0743de08);
#
#
#
#         marker_142ffea5dfc9bb2fd03bafe8406f8ba2.bindPopup(popup_574ead1ad26543501c66b698f45c7988)
#         ;
#
#
#
#
#             var marker_ae1e38e8730cd513cb44d22d3846116f = L.marker(
#                 [20.69175, -103.36255],
#                 {}
#             ).addTo(map_cfe853c70cf21624c30682c2a64b83c5);
#
#
#         var popup_1720da693784b66405113b65c3c7de81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4dc09d677dd4464d059206912d566691 = $(`&lt;div id=&quot;html_4dc09d677dd4464d059206912d566691&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                                         3 id                                       5 name  (GDL-004) C. Ghilardi /C. Miraflores&lt;/div&gt;`)[0];
#                 popup_1720da693784b66405113b65c3c7de81.setContent(html_4dc09d677dd4464d059206912d566691);
#
#
#
#         marker_ae1e38e8730cd513cb44d22d3846116f.bindPopup(popup_1720da693784b66405113b65c3c7de81)
#         ;
#
#
#
#
#             var marker_7757242d6cd63622119b2c847508897d = L.marker(
#                 [20.6811575, -103.339363],
#                 {}
#             ).addTo(map_cfe853c70cf21624c30682c2a64b83c5);
#
#
#         var popup_be5007bc1ebfcfb0b8e75df59b7f72f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_513087f3f6500f4ac774ff48fc9ab9e1 = $(`&lt;div id=&qu
